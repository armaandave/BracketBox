# %%
import requests
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd
import time

r = open("C:\\Users\\adave\\Desktop\\techPartnersZoom.html", encoding="utf8")
soup = bs(r.read(), "html.parser")
soup_img = soup.findAll("img")
for alt in soup_img:
    print (alt.get("alt"))
# Out:
# Zoom Logo
# 3Ddatacomm
# AboutAV
# Absolut Technologies
# Advanced Presentation Systems
# Apps2Com
# Asnet Technologies
# Audiovisual Projects
# AV Agents LLC
# AVANT Communications
# AV8 Technologies
# AVCS LTD
# AVEX B.V.
# AVI Systems
# Avidex Industries
# AVMI
# Ayno
# Bug ID Inc
# Cal Coast Telecom
# CamWave S.R.L.
# Carousel Industries
# CBI-Technologies
# CCS Presentation Systems
# CoitCom
# Colortone Audio Visual
# Conekt
# Connect NZ
# Coral Vision
# Corbett Technology Solutions
# Cowbell Technologies, Inc.
# Cytek Media Systems
# David Carroll Associates, Inc.
# Design Integration
# DGI Technologies
# DYOOTRUST
# DYXnet
# ESCO
# Felix Media Solutions
# Feltech
# Ford Audio-Video
# Genesis Integration
# Global Interactive Solutions, LLC
# HB Communications Inc
# HSI
# ICAP GLOBAL
# Ideas Ahead AV Solutions Private Limited
# IDEAL-Audio Visual
# Immedia Integrated Technologies
# Infoscert Xpression Streams Limited
# Integrated Communication Systems
# Intelisys
# ...

# %%
print (soup_img)
# Out:
# []
