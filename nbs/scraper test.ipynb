# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
r = requests.get('https://enlyft.com')
soup =  bs(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 9]><html class="lt-ie10" lang="en"> <![endif]-->
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="#FFFFFF" name="msapplication-TileColor"/>
# <link href="https://enlyft.com/wp-content/themes/enlyft/assets/img/favicon.png" rel="icon" type="image/png"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-43668823-4"></script>
# <script>
# 	  window.dataLayer = window.dataLayer || [];
# 	  function gtag(){dataLayer.push(arguments);}
# 	  gtag('js', new Date());
#
# 	  gtag('config', 'UA-43668823-4', { 'optimize_id': 'GTM-KG79484'});
#       /*gtag('config', 'UA-43668823-4');  */
#
# 	  var wpcfDemo = document.querySelector('#im-interested');
#
#       document.addEventListener( 'wpcf7mailsent', function( event ) {
# ...
