# %%
#imports
import pandas as pd 
from tqdm.notebook import tqdm
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df = pd.read_csv('/Users/armaan/src/bbox/mdata/final_result/master_table.csv')
df.drop(["bb_profit_multiple_score", "bb_profit_multiple"], axis=1, inplace = True)

# %%
new_df = df
bins = [1980,1985,1990,1995,2000, 2005, 2010, 2015, 2020]
new_df['binned'] = pd.cut(new_df['year'], bins)
year_df = df.groupby('binned').mean()
genre_df = df.groupby('genre').mean()
genre_df
genre_df.drop(["year"], axis=1, inplace = True)
genre_df.to_csv('/Users/armaan/src/bbox/mdata/final_result/genre_table.csv')

# %%
genres = df.genre.unique()
dfs = []
for g in genres:
    dfgenre = df[df.genre == g]
    dfgenre['binned'] = pd.cut(dfgenre['year'], bins)
    dfgmean = dfgenre.groupby('binned').mean()
    dfgmean['genre'] = g
    dfs.append(dfgmean)
len(dfs)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 10

# %%
dfall = pd.concat(dfs)
dfall
# Out:
#               year  domestic_box_office  international_box_office  \
# binned
# (1980, 1985]   nan                  nan                       nan
# (1985, 1990]   nan                  nan                       nan
# (1990, 1995]   nan                  nan                       nan
# (1995, 2000]   nan                  nan                       nan
# (2000, 2005]   nan                  nan                       nan
# ...            ...                  ...                       ...
# (1995, 2000]   nan                  nan                       nan
# (2000, 2005]   nan                  nan                       nan
# (2005, 2010]   nan                  nan                       nan
# (2010, 2015]   nan                  nan                       nan
# (2015, 2020]   nan                  nan                       nan
#
#               worldwide_box_office  opening_weekend  legs  production_budget  \
# binned
# (1980, 1985]                   nan              nan   nan                nan
# (1985, 1990]                   nan              nan   nan                nan
# (1990, 1995]                   nan              nan   nan                nan
# (1995, 2000]                   nan              nan   nan                nan
# (2000, 2005]                   nan              nan   nan                nan
# ...                            ...              ...   ...                ...
# (1995, 2000]                   nan              nan   nan                nan
# (2000, 2005]                   nan              nan   nan                nan
# (2005, 2010]                   nan              nan   nan                nan
# (2010, 2015]                   nan              nan   nan                nan
# (2015, 2020]                   nan              nan   nan                nan
#
#               theater_counts  running_time  bb_profit  bb_profit_score  \
# binned
# (1980, 1985]             nan           nan        nan              nan
# (1985, 1990]             nan           nan        nan              nan
# (1990, 1995]             nan           nan        nan              nan
# (1995, 2000]             nan           nan        nan              nan
# (2000, 2005]             nan           nan        nan              nan
# ...                      ...           ...        ...              ...
# (1995, 2000]             nan           nan        nan              nan
# (2000, 2005]             nan           nan        nan              nan
# (2005, 2010]             nan           nan        nan              nan
# (2010, 2015]             nan           nan        nan              nan
# (2015, 2020]             nan           nan        nan              nan
#
#               bb_score    genre
# binned
# (1980, 1985]       nan      NaN
# (1985, 1990]       nan      NaN
# (1990, 1995]       nan      NaN
# (1995, 2000]       nan      NaN
# (2000, 2005]       nan      NaN
# ...                ...      ...
# (1995, 2000]       nan  Western
# (2000, 2005]       nan  Western
# (2005, 2010]       nan  Western
# (2010, 2015]       nan  Western
# (2015, 2020]       nan  Western
#
# [80 rows x 13 columns]

# %%
df.to_csv('/Users/armaan/src/bbox/mdata/final_result/binned_table.csv')

# %%
year_df['genre'] = 'All'
year_df
# Out:
#                 year  domestic_box_office  international_box_office  \
# binned
# (1980, 1985] 1983.50         220562043.90              141027081.70
# (1985, 1990] 1988.63         138688646.37              127782047.20
# (1990, 1995] 1993.28         137727894.17              164913748.00
# (1995, 2000] 1998.22         143967064.28              161057667.92
# (2000, 2005] 2002.99         156618855.72              167050421.68
# (2005, 2010] 2008.16         162793439.49              218233291.36
# (2010, 2015] 2013.03         174037264.34              279433306.26
# (2015, 2020] 2017.49         209563924.12              344625375.32
#
#               worldwide_box_office  opening_weekend  production_budget  \
# binned
# (1980, 1985]          361589125.60      14531277.90        19222222.22
# (1985, 1990]          266470693.57      15745845.16        28526923.08
# (1990, 1995]          302641642.17      20107485.47        48794000.00
# (1995, 2000]          305024732.19      26649660.14        68549452.94
# (2000, 2005]          323669277.41      39469736.68        76090378.19
# (2005, 2010]          381026730.85      45123751.89       100156804.73
# (2010, 2015]          453470570.60      51904698.66       107922751.32
# (2015, 2020]          554189299.44      64529619.35       116895744.68
#
#               theater_counts  running_time    bb_profit  bb_profit_score  \
# binned
# (1980, 1985]           19.25        110.40 349168615.56            13.68
# (1985, 1990]           13.26        115.03 256474028.81            10.05
# (1990, 1995]           10.76        120.14 271542631.90            10.64
# (1995, 2000]            9.85        115.43 241196890.61             9.45
# (2000, 2005]            7.55        115.40 248077344.65             9.72
# (2005, 2010]            6.63        112.80 284596285.12            11.15
# (2010, 2015]            6.43        117.44 345547819.28            13.54
# (2015, 2020]            6.40        118.85 439845622.99            17.24
#
#               bb_score genre
# binned
# (1980, 1985]     39.58   All
# (1985, 1990]     37.04   All
# (1990, 1995]     37.45   All
# (1995, 2000]     36.62   All
# (2000, 2005]     36.81   All
# (2005, 2010]     37.81   All
# (2010, 2015]     39.48   All
# (2015, 2020]     42.07   All

# %%
df_final_means = pd.concat([dfall, year_df])
df_final_means.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 88 entries, (1980, 1985] to (2015, 2020]
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      37 non-null     float64
#  1   domestic_box_office       37 non-null     float64
#  2   international_box_office  37 non-null     float64
#  3   worldwide_box_office      37 non-null     float64
#  4   opening_weekend           37 non-null     float64
#  5   legs                      37 non-null     float64
#  6   production_budget         34 non-null     float64
#  7   theater_counts            37 non-null     float64
#  8   running_time              35 non-null     float64
#  9   bb_profit                 34 non-null     float64
#  10  bb_profit_score           34 non-null     float64
#  11  bb_score                  34 non-null     float64
#  12  genre                     72 non-null     object
# dtypes: float64(12), object(1)
# memory usage: 9.5+ KB

# %%
df_final_means
# Out:
#                 year  domestic_box_office  international_box_office  \
# binned
# (1980, 1985]     nan                  nan                       nan
# (1985, 1990]     nan                  nan                       nan
# (1990, 1995]     nan                  nan                       nan
# (1995, 2000]     nan                  nan                       nan
# (2000, 2005]     nan                  nan                       nan
# ...              ...                  ...                       ...
# (1995, 2000] 1998.22         143967064.28              161057667.92
# (2000, 2005] 2002.99         156618855.72              167047680.39
# (2005, 2010] 2008.16         162793439.49              218225832.45
# (2010, 2015] 2013.03         174037264.34              279364720.86
# (2015, 2020] 2017.49         209563924.12              344661163.46
#
#               worldwide_box_office  opening_weekend  legs  production_budget  \
# binned
# (1980, 1985]                   nan              nan   nan                nan
# (1985, 1990]                   nan              nan   nan                nan
# (1990, 1995]                   nan              nan   nan                nan
# (1995, 2000]                   nan              nan   nan                nan
# (2000, 2005]                   nan              nan   nan                nan
# ...                            ...              ...   ...                ...
# (1995, 2000]          305024732.19      26649660.14  3.78        68549452.94
# (2000, 2005]          323666536.11      39469736.68  3.78        76090378.19
# (2005, 2010]          381019271.94      45123751.89  3.78       100156804.73
# (2010, 2015]          453401985.21      51904698.66  3.78       107922751.32
# (2015, 2020]          554225087.58      64529619.35  3.78       116895744.68
#
#               theater_counts  running_time    bb_profit  bb_profit_score  \
# binned
# (1980, 1985]             nan           nan          nan              nan
# (1985, 1990]             nan           nan          nan              nan
# (1990, 1995]             nan           nan          nan              nan
# (1995, 2000]             nan           nan          nan              nan
# (2000, 2005]             nan           nan          nan              nan
# ...                      ...           ...          ...              ...
# (1995, 2000]            9.85        109.97 241196890.61             9.45
# (2000, 2005]            7.55        106.30 248074584.71             9.72
# (2005, 2010]            6.63        110.00 284588649.66            11.15
# (2010, 2015]            6.43           nan 345479233.88            13.54
# (2015, 2020]            6.40           nan 439882134.81            17.24
#
#               bb_score genre
# binned
# (1980, 1985]       nan   NaN
# (1985, 1990]       nan   NaN
# (1990, 1995]       nan   NaN
# (1995, 2000]       nan   NaN
# (2000, 2005]       nan   NaN
# ...                ...   ...
# (1995, 2000]     36.62   NaN
# (2000, 2005]     36.81   NaN
# (2005, 2010]     37.81   NaN
# (2010, 2015]     39.48   NaN
# (2015, 2020]     42.07   NaN
#
# [88 rows x 13 columns]

# %%
binned_table = pd.read_csv('/Users/armaan/src/bbox/mdata/final_result/master_binned_table.csv')
binned_table
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-d2699fc19b95> in <module>
# ----> 1 binned_table = pd.read_csv('/Users/armaan/src/bbox/mdata/final_result/master_binned_table.csv')
#       2 binned_table
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /Users/armaan/src/bbox/mdata/final_result/master_binned_table.csv does not exist: '/Users/armaan/src/bbox/mdata/final_result/master_binned_table.csv'
